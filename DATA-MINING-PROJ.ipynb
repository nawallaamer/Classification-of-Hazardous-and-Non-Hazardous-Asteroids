# %% [markdown]
# # **PROJECT BY:**
# # **Abdul Hadi Durrani (21L-5630)**
# # **Nawall Aamer       (21L-5620)**
# # **Abdullah Awan      (21L-5663)**
# # **Soha Bilal         (21L-6258)**

# %% [markdown]
# # **Loading Dataset**

# %%
import pandas as pd

nasa_df = pd.read_csv("nasa.csv")

nasa_df
# Out:
#       Neo Reference ID     Name  Absolute Magnitude  Est Dia in KM(min)  \
# 0              3703080  3703080              21.600            0.127220
# 1              3723955  3723955              21.300            0.146068
# 2              2446862  2446862              20.300            0.231502
# 3              3092506  3092506              27.400            0.008801
# 4              3514799  3514799              21.600            0.127220
# ...                ...      ...                 ...                 ...
# 4682           3759007  3759007              23.900            0.044112
# 4683           3759295  3759295              28.200            0.006089
# 4684           3759714  3759714              22.700            0.076658
# 4685           3759720  3759720              21.800            0.116026
# 4686           3772978  3772978              19.109            0.400641
#
#       Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# 0               0.284472         127.219879         284.472297
# 1               0.326618         146.067964         326.617897
# 2               0.517654         231.502122         517.654482
# 3               0.019681           8.801465          19.680675
# 4               0.284472         127.219879         284.472297
# ...                  ...                ...                ...
# 4682            0.098637          44.111820          98.637028
# 4683            0.013616           6.089126          13.615700
# 4684            0.171412          76.657557         171.411509
# 4685            0.259442         116.025908         259.441818
# 4686            0.895860         400.640618         895.859655
#
#       Est Dia in Miles(min)  Est Dia in Miles(max)  Est Dia in Feet(min)  ...  \
# 0                  0.079051               0.176763            417.388066  ...
# 1                  0.090762               0.202951            479.225620  ...
# 2                  0.143849               0.321655            759.521423  ...
# 3                  0.005469               0.012229             28.876199  ...
# 4                  0.079051               0.176763            417.388066  ...
# ...                     ...                    ...                   ...  ...
# 4682               0.027410               0.061290            144.723824  ...
# 4683               0.003784               0.008460             19.977449  ...
# 4684               0.047633               0.106510            251.501180  ...
# 4685               0.072095               0.161210            380.662441  ...
# 4686               0.248946               0.556661           1314.437764  ...
#
#       Asc Node Longitude Orbital Period  Perihelion Distance  Perihelion Arg  \
# 0             314.373913     609.599786             0.808259       57.257470
# 1             136.717242     425.869294             0.718200      313.091975
# 2             259.475979     643.580228             0.950791      248.415038
# 3              57.173266     514.082140             0.983902       18.707701
# 4              84.629307     495.597821             0.967687      158.263596
# ...                  ...            ...                  ...             ...
# 4682          164.183305     457.179984             0.741558      276.395697
# 4683          345.225230     407.185767             0.996434       42.111064
# 4684           37.026468     690.054279             0.965760      274.692712
# 4685          163.802910     662.048343             1.185467      180.346090
# 4686          187.642183     653.679098             0.876110      222.436688
#
#       Aphelion Dist  Perihelion Time  Mean Anomaly  Mean Motion  Equinox  \
# 0          2.005764     2.458162e+06    264.837533     0.590551    J2000
# 1          1.497352     2.457795e+06    173.741112     0.845330    J2000
# 2          1.966857     2.458120e+06    292.893654     0.559371    J2000
# 3          1.527904     2.457902e+06     68.741007     0.700277    J2000
# 4          1.483543     2.457814e+06    135.142133     0.726395    J2000
# ...             ...              ...           ...          ...      ...
# 4682       1.581299     2.457708e+06    304.306025     0.787436    J2000
# 4683       1.153835     2.458088e+06    282.978786     0.884117    J2000
# 4684       2.090708     2.458300e+06    203.501147     0.521698    J2000
# 4685       1.787733     2.458288e+06    203.524965     0.543767    J2000
# 4686       2.071980     2.458319e+06    184.820424     0.550729    J2000
#
#       Hazardous
# 0          True
# 1         False
# 2          True
# 3         False
# 4          True
# ...         ...
# 4682      False
# 4683      False
# 4684      False
# 4685      False
# 4686      False
#
# [4687 rows x 40 columns]

# %% [markdown]
# # **Data preprocessing**

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA

categorical_cols = ['Orbiting Body', 'Equinox']
numerical_cols = nasa_df.select_dtypes(include=['float64', 'int64']).columns.tolist()

X = nasa_df.drop(columns=["Hazardous"])
y = nasa_df["Hazardous"]

numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy="mean")),
    ('scaler', StandardScaler()),
    ('pca', PCA())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy="most_frequent")),  # Impute missing values with most frequent value
    ('onehot', OneHotEncoder(handle_unknown='ignore'))  # One-hot encode categorical features
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

X_preprocessed = preprocessor.fit_transform(X)

X_preprocessed_df = pd.DataFrame(X_preprocessed)

X_preprocessed_df
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.693150 -0.460071 -0.818540 -2.203207  0.277694  0.476904 -1.811763
# 1     0.304192 -2.071261 -1.829049 -0.196947  0.404273  0.337610  1.171755
# 2     0.014228  1.446778  2.663526 -0.200534 -2.103022 -2.365363 -0.096232
# 3    -2.039890 -0.718712  0.097973 -0.972221  0.321273 -0.321015 -0.570008
# 4    -0.312831 -1.517848 -0.703017 -2.091346  0.488106 -0.302666 -0.146914
# ...        ...       ...       ...       ...       ...       ...       ...
# 4682 -2.031572  0.215928  0.212732  3.318531 -0.564378  1.393057  2.783288
# 4683 -4.283857  0.678643  3.652293 -0.557598 -0.674665  1.371107  0.700730
# 4684 -2.485151  2.260153  1.579458 -0.176985 -0.861469  1.025309  0.441163
# 4685 -1.115323  0.796923 -0.535635 -1.670979  0.217072  1.101708  1.887658
# 4686  3.199566 -1.279848 -4.637691  1.987555  0.600485  2.536566  2.583900
#
#             7         8         9   ...            27            28  \
# 0     2.189444  0.303156 -0.196594  ...  1.022599e-11 -3.378714e-13
# 1    -0.631356  0.691116  0.603633  ... -1.829608e-11  4.908570e-12
# 2     0.640978  0.814891  0.575091  ...  1.871376e-11 -4.683762e-12
# 3     0.124615 -1.568313 -1.659214  ... -4.369832e-12 -5.500569e-13
# 4    -0.235401 -0.663667 -0.424785  ...  1.741268e-11  2.129981e-12
# ...        ...       ...       ...  ...           ...           ...
# 4682 -0.015328  0.303055  1.401427  ... -3.131991e-11  1.339130e-12
# 4683  2.121554  0.250902 -0.239718  ...  3.591865e-11 -2.273873e-12
# 4684 -1.366754 -0.654154  0.894865  ... -2.152174e-11  3.756179e-12
# 4685  0.037927 -0.031510  0.367793  ... -1.886211e-11  4.719213e-13
# 4686 -0.055866  0.492496  0.309092  ...  2.688104e-11  5.344058e-12
#
#                 29            30            31            32            33  \
# 0    -1.006563e-13  7.720658e-15 -2.593471e-14  4.783212e-15  4.374844e-14
# 1    -9.057607e-14  4.231214e-14  2.242273e-14 -6.846370e-15  5.272836e-19
# 2     6.873354e-14  3.874769e-14  2.680840e-14  2.795974e-15 -1.959514e-17
# 3    -1.983869e-14 -1.697284e-14  2.220176e-14 -3.241352e-15  3.616913e-17
# 4    -1.001062e-13  4.181049e-15 -1.870041e-14 -4.101530e-15 -1.260859e-16
# ...            ...           ...           ...           ...           ...
# 4682 -3.450563e-14 -4.378963e-14 -3.520950e-15  1.247338e-15 -3.380107e-17
# 4683 -1.188411e-13  3.067314e-14 -4.156971e-15 -3.212910e-16 -8.584445e-17
# 4684  1.744481e-14 -4.158475e-14 -2.773251e-14 -2.013854e-15  4.658043e-17
# 4685  5.281952e-14 -3.642627e-14  3.773770e-14 -1.197152e-15  6.307971e-17
# 4686 -9.528662e-14 -6.328213e-15  1.446034e-14 -3.988010e-16  4.663280e-17
#
#                 34   35   36
# 0     9.954236e-18  1.0  1.0
# 1    -6.257004e-16  1.0  1.0
# 2     7.598006e-16  1.0  1.0
# 3    -1.948072e-17  1.0  1.0
# 4     9.324523e-17  1.0  1.0
# ...            ...  ...  ...
# 4682 -8.640783e-16  1.0  1.0
# 4683  3.861818e-16  1.0  1.0
# 4684  4.720115e-16  1.0  1.0
# 4685  5.661716e-16  1.0  1.0
# 4686  6.157944e-16  1.0  1.0
#
# [4687 rows x 37 columns]

# %% [markdown]
# # **Feature Extraction Method (Recursive Feature Elimination)**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numerical_columns = nasa_df.select_dtypes(include=['number'])

# correlation matrix
correlation_matrix = numerical_columns.corr()

plt.figure(figsize=(24, 18))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier

numeric_df = nasa_df.select_dtypes(include=['number'])

X_numeric = numeric_df
y_numeric = nasa_df["Hazardous"]

# Initializing model for RFE
model = RandomForestClassifier()

# Initializing RFE
rfe = RFE(model, n_features_to_select=10)

rfe.fit(X_numeric, y_numeric)

selected_features = X_numeric.columns[rfe.support_]
print("Selected Features:", selected_features)
# Out:
# Selected Features: Index(['Absolute Magnitude', 'Est Dia in KM(min)', 'Est Dia in M(min)',
#        'Est Dia in M(max)', 'Est Dia in Miles(min)', 'Est Dia in Miles(max)',
#        'Est Dia in Feet(min)', 'Minimum Orbit Intersection', 'Inclination',
#        'Perihelion Distance'],
#       dtype='object')

# %% [markdown]
# # **Wrapper Method (Forward Feature Selection)**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.ensemble import RandomForestClassifier

# Drop non-numeric columns and columns that are not relevant for feature selection
X_numeric = nasa_df.drop(columns=['Neo Reference ID', 'Name', 'Close Approach Date', 'Orbit Determination Date', 'Equinox', 'Hazardous'])

X_encoded = pd.get_dummies(X_numeric)

y = nasa_df['Hazardous']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Initialize a random forest classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)

# Perform forward feature selection
selector = SequentialFeatureSelector(clf,
                                     n_features_to_select=10,  # Number of features to select
                                     direction='forward',  # Forward selection
                                     scoring='accuracy',
                                     cv=5)

# Fit the selector to the training data
selector = selector.fit(X_train, y_train)

# Get the selected feature indices
selected_feature_indices = selector.get_support(indices=True)

# Get the selected feature names
selected_feature_names = X_train.columns[selected_feature_indices]

print("Selected Features:")
print(selected_feature_names)
# Out:
# Selected Features:
# Index(['Absolute Magnitude', 'Est Dia in KM(min)', 'Epoch Date Close Approach',
#        'Orbit ID', 'Minimum Orbit Intersection', 'Inclination',
#        'Perihelion Arg', 'Perihelion Time', 'Mean Anomaly',
#        'Orbiting Body_Earth'],
#       dtype='object')

# %% [markdown]
# # **Data Visualization**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Scatter Plot: Relative Velocity vs. Miss Distance (Miles) using selected features
features = ['Relative Velocity km per hr', 'Miss Dist.(miles)']
selected_df = nasa_df[features]

plt.figure(figsize=(8, 5))
sns.scatterplot(x=selected_df.columns[0], y=selected_df.columns[1], data=selected_df)
plt.title('Scatter Plot: Relative Velocity vs. Miss Distance (Selected Features)')
plt.xlabel(selected_df.columns[0])
plt.ylabel(selected_df.columns[1])
plt.show()

# %%
# Bar Plot: Number of hazardous vs. non-hazardous objects
plt.figure(figsize=(8, 5))
sns.countplot(x='Hazardous', data=nasa_df)
plt.title('Bar Plot: Number of Hazardous vs. Non-Hazardous Objects')
plt.xlabel('Hazardous')
plt.ylabel('Count')
plt.show()

# %%
# Histogram: Distribution of Absolute Magnitude using selected feature
feature = 'Absolute Magnitude'

plt.figure(figsize=(8, 5))
sns.histplot(x=feature, data=nasa_df, bins=20, kde=True)
plt.title('Histogram: Distribution of Absolute Magnitude (Selected Feature)')
plt.xlabel(feature)
plt.ylabel('Frequency')
plt.show()

# %%
# Box Plot: Distribution of Absolute Magnitude by Hazardous using selected features
features = ['Hazardous', 'Absolute Magnitude']
selected_df = nasa_df[features]

plt.figure(figsize=(8, 5))
sns.boxplot(x=selected_df.columns[0], y=selected_df.columns[1], data=selected_df)
plt.title('Box Plot: Distribution of Absolute Magnitude by Hazardous (Selected Features)')
plt.xlabel(selected_df.columns[0])
plt.ylabel(selected_df.columns[1])
plt.show()

# %% [markdown]
# # **Checking for class imbalance**

# %%
# Checking class distribution
class_distribution = nasa_df['Hazardous'].value_counts()
print("Class Distribution:\n", class_distribution)

# Calculating the imbalance ratio
imbalance_ratio = class_distribution[0] / class_distribution[1]
print("\nImbalance Ratio:", imbalance_ratio)
# Out:
# Class Distribution:
#  Hazardous
# False    3932
# True      755
# Name: count, dtype: int64
#
# Imbalance Ratio: 5.207947019867549

# %%
from imblearn.over_sampling import RandomOverSampler

# Creating an oversampler object
oversampler = RandomOverSampler(random_state=42)

# Resampling the dataset
X_resampled, y_resampled = oversampler.fit_resample(nasa_df[selected_features], y)

# Checking the class distribution after oversampling
class_distribution_resampled = pd.Series(y_resampled).value_counts()
print("Class Distribution after Oversampling:\n", class_distribution_resampled)

# Calculating the imbalance ratio after oversampling
imbalance_ratio_resampled = class_distribution_resampled[0] / class_distribution_resampled[1]
print("\nImbalance Ratio after Oversampling:", imbalance_ratio_resampled)
# Out:
# Class Distribution after Oversampling:
#  Hazardous
# True     3932
# False    3932
# Name: count, dtype: int64
#
# Imbalance Ratio after Oversampling: 1.0

# %% [markdown]
# # **Different Models.**

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# Split the data into training and testing sets

train_x, test_x, train_y, test_y = train_test_split(X_resampled, y_resampled, test_size=0.25, random_state=42)

# Preprocessing pipeline
numeric_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, selected_features)
    ])

# Defining models
models = [
    LogisticRegression(max_iter=1000),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    SVC(),
    KNeighborsClassifier(),
    GaussianNB(),
    AdaBoostClassifier(),
    GradientBoostingClassifier()
]

# Evaluating each model using cross-validation
for model in models:
    pipe = Pipeline(steps=[('preprocessor', preprocessor), ('classifier', model)])
    scores = cross_val_score(pipe, train_x, train_y, cv=5, scoring='f1')
    print(f"{model.__class__.__name__}: Mean F1_score = {scores.mean()}, Std = {scores.std()}")
# Out:
# LogisticRegression: Mean F1_score = 0.9419686272241762, Std = 0.009396471540072874
# DecisionTreeClassifier: Mean F1_score = 0.9981471488991966, Std = 0.001718775360915327
# RandomForestClassifier: Mean F1_score = 0.9981468630834307, Std = 0.0013479919994717772
# SVC: Mean F1_score = 0.9692552955305509, Std = 0.002666995335058579
# KNeighborsClassifier: Mean F1_score = 0.9679805229722953, Std = 0.005235426650286958
# GaussianNB: Mean F1_score = 0.9303181329990746, Std = 0.021072821852462932
# AdaBoostClassifier: Mean F1_score = 0.9983179089759553, Std = 0.001404635003967381
# GradientBoostingClassifier: Mean F1_score = 0.9983176298437687, Std = 0.0009200258906256389

# %% [markdown]
# # **Cross-validation and grid search CV**

# %%
from sklearn.model_selection import GridSearchCV

# Defining parameter grid for each model with different hyperparameters
param_grid = {
    LogisticRegression.__name__.lower(): {
        'classifier__C': [0.001, 0.01, 0.1, 1, 10, 100],
    },
    DecisionTreeClassifier.__name__.lower(): {
        'classifier__max_depth': [None, 5, 10, 15, 20],
    },
    RandomForestClassifier.__name__.lower(): {
        'classifier__n_estimators': [100, 200, 300],
    },
    SVC.__name__.lower(): {
        'classifier__C': [0.1, 1, 10],
    },
    KNeighborsClassifier.__name__.lower(): {
        'classifier__n_neighbors': [3, 5, 7],
    },
    GaussianNB.__name__.lower(): {},
    AdaBoostClassifier.__name__.lower(): {
        'classifier__n_estimators': [50, 100, 200],
    },
    GradientBoostingClassifier.__name__.lower(): {
        'classifier__n_estimators': [50, 100, 200],
        'classifier__max_depth': [3, 5, 7],
        'classifier__learning_rate': [0.01, 0.1, 0.5]
    }
}

# Defining grid search for each model
grid_searches = []
for model in models:
    model_name_lower = model.__class__.__name__.lower()
    pipe = Pipeline(steps=[('preprocessor', preprocessor), ('classifier', model)])
    grid_search = GridSearchCV(pipe, param_grid=param_grid[model_name_lower], cv=5, scoring='f1', n_jobs=-1)
    grid_search.fit(train_x, train_y)
    grid_searches.append(grid_search)

for i, grid_search in enumerate(grid_searches):
    model_name = models[i].__class__.__name__
    print(f"{model_name}: Best Parameters - {grid_search.best_params_}, Best Score - {grid_search.best_score_}")
# Out:
# LogisticRegression: Best Parameters - {'classifier__C': 0.1}, Best Score - 0.9452247903984695
# DecisionTreeClassifier: Best Parameters - {'classifier__max_depth': None}, Best Score - 0.9981471488991966
# RandomForestClassifier: Best Parameters - {'classifier__n_estimators': 300}, Best Score - 0.9986540467624764
# SVC: Best Parameters - {'classifier__C': 10}, Best Score - 0.9843756139213132
# KNeighborsClassifier: Best Parameters - {'classifier__n_neighbors': 3}, Best Score - 0.9753612731626642
# GaussianNB: Best Parameters - {}, Best Score - 0.9303181329990746
# AdaBoostClassifier: Best Parameters - {'classifier__n_estimators': 50}, Best Score - 0.9983179089759553
# GradientBoostingClassifier: Best Parameters - {'classifier__learning_rate': 0.1, 'classifier__max_depth': 5, 'classifier__n_estimators': 200}, Best Score - 0.9993268822674573

# %% [markdown]
# # **Accuracy measures**

# %%
from sklearn.metrics import classification_report

for i, grid_search in enumerate(grid_searches):
    model_name = models[i].__class__.__name__
    y_pred = grid_search.predict(test_x)
    print(f"{model_name}:")
    print(classification_report(test_y, y_pred))
# Out:
# LogisticRegression:
#               precision    recall  f1-score   support
#
#        False       0.98      0.91      0.94      1001
#         True       0.91      0.98      0.95       965
#
#     accuracy                           0.94      1966
#    macro avg       0.95      0.95      0.94      1966
# weighted avg       0.95      0.94      0.94      1966
#
# DecisionTreeClassifier:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1001
#         True       1.00      1.00      1.00       965
#
#     accuracy                           1.00      1966
#    macro avg       1.00      1.00      1.00      1966
# weighted avg       1.00      1.00      1.00      1966
#
# RandomForestClassifier:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1001
#         True       1.00      1.00      1.00       965
#
#     accuracy                           1.00      1966
#    macro avg       1.00      1.00      1.00      1966
# weighted avg       1.00      1.00      1.00      1966
#
# SVC:
#               precision    recall  f1-score   support
#
#        False       1.00      0.98      0.99      1001
#         True       0.97      1.00      0.99       965
#
#     accuracy                           0.99      1966
#    macro avg       0.99      0.99      0.99      1966
# weighted avg       0.99      0.99      0.99      1966
#
# KNeighborsClassifier:
#               precision    recall  f1-score   support
#
#        False       1.00      0.96      0.98      1001
#         True       0.96      1.00      0.98       965
#
#     accuracy                           0.98      1966
#    macro avg       0.98      0.98      0.98      1966
# weighted avg       0.98      0.98      0.98      1966
#
# GaussianNB:
#               precision    recall  f1-score   support
#
#        False       0.95      0.89      0.92      1001
#         True       0.89      0.95      0.92       965
#
#     accuracy                           0.92      1966
#    macro avg       0.92      0.92      0.92      1966
# weighted avg       0.92      0.92      0.92      1966
#
# AdaBoostClassifier:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1001
#         True       1.00      1.00      1.00       965
#
#     accuracy                           1.00      1966
#    macro avg       1.00      1.00      1.00      1966
# weighted avg       1.00      1.00      1.00      1966
#
# GradientBoostingClassifier:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1001
#         True       1.00      1.00      1.00       965
#
#     accuracy                           1.00      1966
#    macro avg       1.00      1.00      1.00      1966
# weighted avg       1.00      1.00      1.00      1966

# %% [markdown]
# # **Explainable AI models**

# %%
# !pip install lime
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lime in c:\users\durrani\appdata\roaming\python\python311\site-packages (0.2.0.1)
# Requirement already satisfied: matplotlib in c:\users\durrani\appdata\roaming\python\python311\site-packages (from lime) (3.8.0)
# Requirement already satisfied: numpy in c:\users\durrani\appdata\roaming\python\python311\site-packages (from lime) (1.25.1)
# Requirement already satisfied: scipy in c:\users\durrani\appdata\roaming\python\python311\site-packages (from lime) (1.11.2)
# Requirement already satisfied: tqdm in c:\users\durrani\appdata\roaming\python\python311\site-packages (from lime) (4.65.0)
# Requirement already satisfied: scikit-learn>=0.18 in c:\users\durrani\appdata\roaming\python\python311\site-packages (from lime) (1.3.1)
# Requirement already satisfied: scikit-image>=0.12 in c:\users\durrani\appdata\roaming\python\python311\site-packages (from lime) (0.23.2)
# Requirement already satisfied: networkx>=2.8 in c:\users\durrani\appdata\roaming\python\python311\site-packages (from scikit-image>=0.12->lime) (3.2.1)
# Requirement already satisfied: pillow>=9.1 in c:\users\durrani\appdata\roaming\python\python311\site-packages (from scikit-image>=0.12->lime) (10.0.0)
# Requirement already satisfied: imageio>=2.33 in c:\users\durrani\appdata\roaming\python\python311\site-packages (from scikit-image>=0.12->lime) (2.34.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\durrani\appdata\roaming\python\python311\site-packages (from scikit-image>=0.12->lime) (2024.5.10)
# Requirement already satisfied: packaging>=21 in c:\users\durrani\appdata\roaming\python\python311\site-packages (from scikit-image>=0.12->lime) (23.1)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\durrani\appdata\roaming\python\python311\site-packages (from scikit-image>=0.12->lime) (0.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\durrani\appdata\roaming\python\python311\site-packages (from scikit-learn>=0.18->lime) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\durrani\appdata\roaming\python\python311\site-packages (from scikit-learn>=0.18->lime) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\durrani\appdata\roaming\python\python311\site-packages (from matplotlib->lime) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\durrani\appdata\roaming\python\python311\site-packages (from matplotlib->lime) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\durrani\appdata\roaming\python\python311\site-packages (from matplotlib->lime) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\durrani\appdata\roaming\python\python311\site-packages (from matplotlib->lime) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\durrani\appdata\roaming\python\python311\site-packages (from matplotlib->lime) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\durrani\appdata\roaming\python\python311\site-packages (from matplotlib->lime) (2.8.2)
# Requirement already satisfied: colorama in c:\users\durrani\appdata\roaming\python\python311\site-packages (from tqdm->lime) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\durrani\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib->lime) (1.16.0)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
import lime
import lime.lime_tabular

X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

rf_classifier = RandomForestClassifier()

rf_classifier.fit(X_train, y_train)

# Initializing LIME explainer
explainer = lime.lime_tabular.LimeTabularExplainer(X_train.values, mode="classification", feature_names=X_train.columns.tolist())

observation_idx = 0  # Index of the observation we want to explain
exp = explainer.explain_instance(X_test.values[observation_idx], rf_classifier.predict_proba, num_features=5)

print(exp.as_list())
# Out:
# C:\Users\DURRANI\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# [('Minimum Orbit Intersection > 0.06', -0.5235913262875573), ('Perihelion Distance > 0.95', -0.08761027209634907), ('Est Dia in M(max) > 682.40', 0.056974819155674504), ('Est Dia in Miles(min) > 0.19', 0.05388065901909503), ('Est Dia in Miles(max) > 0.42', 0.04618067333507003)]

# %%
# !pip install shap
# Out:
# Requirement already satisfied: shap in /usr/local/lib/python3.10/dist-packages (0.45.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.11.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (2.0.3)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.4)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (24.0)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.10/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.58.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.41.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)

# %%
import shap

# Extracting the best estimator from the grid search
best_estimator = grid_search.best_estimator_['classifier']

# Initializing SHAP explainer
explainer = shap.Explainer(best_estimator)

# Explaining the model's predictions
shap_values = explainer.shap_values(X_test)

shap.summary_plot(shap_values, X_test)

# %% [markdown]
# # **Neural Network**

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.metrics import classification_report

# Defining the neural network architecture
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)

loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}, Test Accuracy: {accuracy}")

# Generating predictions
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

print(classification_report(y_test, y_pred))
# Out:
# Epoch 1/100
# 158/158 [==============================] - 3s 7ms/step - loss: 101.2250 - accuracy: 0.5074 - val_loss: 6.5400 - val_accuracy: 0.5099
# Epoch 2/100
# 158/158 [==============================] - 1s 5ms/step - loss: 22.5511 - accuracy: 0.5173 - val_loss: 0.9844 - val_accuracy: 0.5012
# Epoch 3/100
# 158/158 [==============================] - 1s 5ms/step - loss: 6.5725 - accuracy: 0.5272 - val_loss: 0.6983 - val_accuracy: 0.5012
# Epoch 4/100
# 158/158 [==============================] - 1s 5ms/step - loss: 2.8221 - accuracy: 0.5515 - val_loss: 0.6901 - val_accuracy: 0.5004
# Epoch 5/100
# 158/158 [==============================] - 1s 9ms/step - loss: 1.8062 - accuracy: 0.5797 - val_loss: 0.6968 - val_accuracy: 0.5012
# Epoch 6/100
# 158/158 [==============================] - 1s 8ms/step - loss: 1.3822 - accuracy: 0.5650 - val_loss: 0.6867 - val_accuracy: 0.5012
# Epoch 7/100
# 158/158 [==============================] - 2s 11ms/step - loss: 1.1207 - accuracy: 0.5598 - val_loss: 0.6555 - val_accuracy: 0.5012
# Epoch 8/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.9475 - accuracy: 0.5952 - val_loss: 0.6110 - val_accuracy: 0.5512
# Epoch 9/100
# 158/158 [==============================] - 1s 8ms/step - loss: 0.8448 - accuracy: 0.6105 - val_loss: 0.5897 - val_accuracy: 0.5004
# Epoch 10/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8056 - accuracy: 0.6008 - val_loss: 0.5844 - val_accuracy: 0.5036
# Epoch 11/100
# 158/158 [==============================] - 1s 7ms/step - loss: 0.8046 - accuracy: 0.6089 - val_loss: 0.5649 - val_accuracy: 0.7141
# Epoch 12/100
# 158/158 [==============================] - 1s 7ms/step - loss: 0.6595 - accuracy: 0.6636 - val_loss: 0.5289 - val_accuracy: 0.7506
# Epoch 13/100
# 158/158 [==============================] - 1s 8ms/step - loss: 0.6302 - accuracy: 0.6691 - val_loss: 0.5284 - val_accuracy: 0.7355
# Epoch 14/100
# 158/158 [==============================] - 2s 11ms/step - loss: 0.7369 - accuracy: 0.6806 - val_loss: 0.5274 - val_accuracy: 0.7299
# Epoch 15/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.6313 - accuracy: 0.6892 - val_loss: 0.5109 - val_accuracy: 0.7434
# Epoch 16/100
# 158/158 [==============================] - 2s 11ms/step - loss: 0.6330 - accuracy: 0.6892 - val_loss: 0.4824 - val_accuracy: 0.7752
# Epoch 17/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.5670 - accuracy: 0.7069 - val_loss: 0.4760 - val_accuracy: 0.7752
# Epoch 18/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.5465 - accuracy: 0.7178 - val_loss: 0.4790 - val_accuracy: 0.7673
# Epoch 19/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.5493 - accuracy: 0.7081 - val_loss: 0.4560 - val_accuracy: 0.7951
# Epoch 20/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.5265 - accuracy: 0.7200 - val_loss: 0.4659 - val_accuracy: 0.7776
# Epoch 21/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.5130 - accuracy: 0.7289 - val_loss: 0.4470 - val_accuracy: 0.7967
# Epoch 22/100
# 158/158 [==============================] - 1s 8ms/step - loss: 0.5193 - accuracy: 0.7353 - val_loss: 0.4460 - val_accuracy: 0.7927
# Epoch 23/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.5057 - accuracy: 0.7371 - val_loss: 0.4575 - val_accuracy: 0.7776
# Epoch 24/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.5000 - accuracy: 0.7456 - val_loss: 0.4498 - val_accuracy: 0.7824
# Epoch 25/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.5046 - accuracy: 0.7371 - val_loss: 0.4576 - val_accuracy: 0.7752
# Epoch 26/100
# 158/158 [==============================] - 1s 8ms/step - loss: 0.4902 - accuracy: 0.7460 - val_loss: 0.4433 - val_accuracy: 0.7879
# Epoch 27/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.5034 - accuracy: 0.7359 - val_loss: 0.4558 - val_accuracy: 0.7736
# Epoch 28/100
# 158/158 [==============================] - 1s 8ms/step - loss: 0.4894 - accuracy: 0.7480 - val_loss: 0.4576 - val_accuracy: 0.7681
# Epoch 29/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4996 - accuracy: 0.7389 - val_loss: 0.4389 - val_accuracy: 0.7903
# Epoch 30/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4877 - accuracy: 0.7510 - val_loss: 0.4440 - val_accuracy: 0.7832
# Epoch 31/100
# 158/158 [==============================] - 1s 7ms/step - loss: 0.5034 - accuracy: 0.7401 - val_loss: 0.4372 - val_accuracy: 0.7911
# Epoch 32/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4916 - accuracy: 0.7492 - val_loss: 0.4401 - val_accuracy: 0.7855
# Epoch 33/100
# 158/158 [==============================] - 1s 8ms/step - loss: 0.4806 - accuracy: 0.7587 - val_loss: 0.4327 - val_accuracy: 0.7919
# Epoch 34/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4776 - accuracy: 0.7578 - val_loss: 0.4393 - val_accuracy: 0.7840
# Epoch 35/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4811 - accuracy: 0.7562 - val_loss: 0.4480 - val_accuracy: 0.7760
# Epoch 36/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.4875 - accuracy: 0.7502 - val_loss: 0.4325 - val_accuracy: 0.7959
# Epoch 37/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.4921 - accuracy: 0.7464 - val_loss: 0.4317 - val_accuracy: 0.7935
# Epoch 38/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4765 - accuracy: 0.7603 - val_loss: 0.4410 - val_accuracy: 0.7840
# Epoch 39/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.4849 - accuracy: 0.7550 - val_loss: 0.4347 - val_accuracy: 0.7919
# Epoch 40/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4830 - accuracy: 0.7516 - val_loss: 0.4472 - val_accuracy: 0.7776
# Epoch 41/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4832 - accuracy: 0.7615 - val_loss: 0.4470 - val_accuracy: 0.7752
# Epoch 42/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4848 - accuracy: 0.7542 - val_loss: 0.4354 - val_accuracy: 0.7919
# Epoch 43/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.4719 - accuracy: 0.7625 - val_loss: 0.4358 - val_accuracy: 0.7895
# Epoch 44/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4732 - accuracy: 0.7607 - val_loss: 0.4555 - val_accuracy: 0.7705
# Epoch 45/100
# 158/158 [==============================] - 1s 6ms/step - loss: 0.4691 - accuracy: 0.7637 - val_loss: 0.4354 - val_accuracy: 0.7879
# Epoch 46/100
# 158/158 [==============================] - 1s 7ms/step - loss: 0.4725 - accuracy: 0.7617 - val_loss: 0.4376 - val_accuracy: 0.7879
# Epoch 47/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4681 - accuracy: 0.7653 - val_loss: 0.4369 - val_accuracy: 0.7855
# Epoch 48/100
# 158/158 [==============================] - 1s 8ms/step - loss: 0.4704 - accuracy: 0.7621 - val_loss: 0.4393 - val_accuracy: 0.7832
# Epoch 49/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.4747 - accuracy: 0.7597 - val_loss: 0.4282 - val_accuracy: 0.7943
# Epoch 50/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4697 - accuracy: 0.7629 - val_loss: 0.4501 - val_accuracy: 0.7752
# Epoch 51/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4699 - accuracy: 0.7643 - val_loss: 0.4577 - val_accuracy: 0.7689
# Epoch 52/100
# 158/158 [==============================] - 2s 11ms/step - loss: 0.4741 - accuracy: 0.7601 - val_loss: 0.4274 - val_accuracy: 0.7951
# Epoch 53/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.4653 - accuracy: 0.7663 - val_loss: 0.4298 - val_accuracy: 0.7951
# Epoch 54/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4696 - accuracy: 0.7633 - val_loss: 0.4290 - val_accuracy: 0.7967
# Epoch 55/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4728 - accuracy: 0.7611 - val_loss: 0.4456 - val_accuracy: 0.7776
# Epoch 56/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4667 - accuracy: 0.7657 - val_loss: 0.4508 - val_accuracy: 0.7760
# Epoch 57/100
# 158/158 [==============================] - 1s 6ms/step - loss: 0.4818 - accuracy: 0.7581 - val_loss: 0.4497 - val_accuracy: 0.7744
# Epoch 58/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.4754 - accuracy: 0.7587 - val_loss: 0.4553 - val_accuracy: 0.7705
# Epoch 59/100
# 158/158 [==============================] - 1s 8ms/step - loss: 0.4671 - accuracy: 0.7645 - val_loss: 0.4321 - val_accuracy: 0.7935
# Epoch 60/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4660 - accuracy: 0.7679 - val_loss: 0.4370 - val_accuracy: 0.7879
# Epoch 61/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.4681 - accuracy: 0.7661 - val_loss: 0.4410 - val_accuracy: 0.7824
# Epoch 62/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4695 - accuracy: 0.7637 - val_loss: 0.4285 - val_accuracy: 0.7990
# Epoch 63/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.4730 - accuracy: 0.7651 - val_loss: 0.4292 - val_accuracy: 0.7959
# Epoch 64/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.4699 - accuracy: 0.7631 - val_loss: 0.4429 - val_accuracy: 0.7808
# Epoch 65/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.4674 - accuracy: 0.7665 - val_loss: 0.4386 - val_accuracy: 0.7847
# Epoch 66/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.4614 - accuracy: 0.7695 - val_loss: 0.4487 - val_accuracy: 0.7752
# Epoch 67/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4615 - accuracy: 0.7693 - val_loss: 0.4359 - val_accuracy: 0.7863
# Epoch 68/100
# 158/158 [==============================] - 1s 7ms/step - loss: 0.4641 - accuracy: 0.7691 - val_loss: 0.4303 - val_accuracy: 0.7951
# Epoch 69/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4656 - accuracy: 0.7663 - val_loss: 0.4431 - val_accuracy: 0.7816
# Epoch 70/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.4664 - accuracy: 0.7655 - val_loss: 0.4452 - val_accuracy: 0.7784
# Epoch 71/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4635 - accuracy: 0.7705 - val_loss: 0.4294 - val_accuracy: 0.7935
# Epoch 72/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.4613 - accuracy: 0.7734 - val_loss: 0.4405 - val_accuracy: 0.7824
# Epoch 73/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.4585 - accuracy: 0.7721 - val_loss: 0.4332 - val_accuracy: 0.7919
# Epoch 74/100
# 158/158 [==============================] - 1s 8ms/step - loss: 0.4595 - accuracy: 0.7699 - val_loss: 0.4407 - val_accuracy: 0.7840
# Epoch 75/100
# 158/158 [==============================] - 1s 6ms/step - loss: 0.4640 - accuracy: 0.7665 - val_loss: 0.4371 - val_accuracy: 0.7927
# Epoch 76/100
# 158/158 [==============================] - 1s 7ms/step - loss: 0.4580 - accuracy: 0.7723 - val_loss: 0.4270 - val_accuracy: 0.7967
# Epoch 77/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4574 - accuracy: 0.7709 - val_loss: 0.4279 - val_accuracy: 0.7951
# Epoch 78/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.4641 - accuracy: 0.7719 - val_loss: 0.4339 - val_accuracy: 0.7943
# Epoch 79/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4581 - accuracy: 0.7723 - val_loss: 0.4285 - val_accuracy: 0.7927
# Epoch 80/100
# 158/158 [==============================] - 2s 11ms/step - loss: 0.4624 - accuracy: 0.7695 - val_loss: 0.4376 - val_accuracy: 0.7855
# Epoch 81/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4554 - accuracy: 0.7772 - val_loss: 0.4337 - val_accuracy: 0.7887
# Epoch 82/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4542 - accuracy: 0.7758 - val_loss: 0.4334 - val_accuracy: 0.7903
# Epoch 83/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.4575 - accuracy: 0.7744 - val_loss: 0.4315 - val_accuracy: 0.7951
# Epoch 84/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4600 - accuracy: 0.7725 - val_loss: 0.4377 - val_accuracy: 0.7855
# Epoch 85/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4560 - accuracy: 0.7750 - val_loss: 0.4428 - val_accuracy: 0.7697
# Epoch 86/100
# 158/158 [==============================] - 2s 11ms/step - loss: 0.4583 - accuracy: 0.7736 - val_loss: 0.4266 - val_accuracy: 0.7935
# Epoch 87/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4564 - accuracy: 0.7729 - val_loss: 0.4339 - val_accuracy: 0.7887
# Epoch 88/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4544 - accuracy: 0.7740 - val_loss: 0.4264 - val_accuracy: 0.7967
# Epoch 89/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.4581 - accuracy: 0.7731 - val_loss: 0.4410 - val_accuracy: 0.7832
# Epoch 90/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4609 - accuracy: 0.7723 - val_loss: 0.4261 - val_accuracy: 0.7951
# Epoch 91/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4516 - accuracy: 0.7774 - val_loss: 0.4335 - val_accuracy: 0.7879
# Epoch 92/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4483 - accuracy: 0.7800 - val_loss: 0.4274 - val_accuracy: 0.7935
# Epoch 93/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.4570 - accuracy: 0.7756 - val_loss: 0.4272 - val_accuracy: 0.7935
# Epoch 94/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.4553 - accuracy: 0.7776 - val_loss: 0.4316 - val_accuracy: 0.7927
# Epoch 95/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4536 - accuracy: 0.7766 - val_loss: 0.4363 - val_accuracy: 0.7863
# Epoch 96/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4579 - accuracy: 0.7721 - val_loss: 0.4297 - val_accuracy: 0.7943
# Epoch 97/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.4552 - accuracy: 0.7736 - val_loss: 0.4300 - val_accuracy: 0.7943
# Epoch 98/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4519 - accuracy: 0.7772 - val_loss: 0.4280 - val_accuracy: 0.7935
# Epoch 99/100
# 158/158 [==============================] - 2s 11ms/step - loss: 0.4550 - accuracy: 0.7766 - val_loss: 0.4358 - val_accuracy: 0.7871
# Epoch 100/100
# 158/158 [==============================] - 1s 5ms/step - loss: 0.4539 - accuracy: 0.7758 - val_loss: 0.4297 - val_accuracy: 0.7959
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4690 - accuracy: 0.7622
# Test Loss: 0.4689743220806122, Test Accuracy: 0.7622377872467041
# 50/50 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#        False       0.99      0.54      0.70       801
#         True       0.68      0.99      0.80       772
#
#     accuracy                           0.76      1573
#    macro avg       0.83      0.77      0.75      1573
# weighted avg       0.83      0.76      0.75      1573

# %% [markdown]
# # **KMeans**

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Extract selected features and target variable
X_selected = nasa_df[selected_features]
y_hazardous = nasa_df['Hazardous']

print(selected_features)
# Encode target variable
y_encoded = y_hazardous.astype(int)

# Apply KMeans clustering
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(X_selected)

# Visualize clusters
plt.figure(figsize=(8, 6))
plt.scatter(X_selected[y_encoded == 0]['Minimum Orbit Intersection'],
            X_selected[y_encoded == 0]['Perihelion Distance'],
            color='blue', label='Non-Hazardous')
plt.scatter(X_selected[y_encoded == 1]['Minimum Orbit Intersection'],
            X_selected[y_encoded == 1]['Perihelion Distance'],
            color='red', label='Hazardous')
plt.title('KMeans Clustering of Hazardous Objects')
plt.xlabel('Minimum Orbit Intersection')
plt.ylabel('Perihelion Distance')
plt.legend()
plt.show()
# Out:
# Index(['Absolute Magnitude', 'Est Dia in KM(min)', 'Est Dia in KM(max)',
#        'Est Dia in M(min)', 'Est Dia in Miles(max)', 'Est Dia in Feet(min)',
#        'Est Dia in Feet(max)', 'Minimum Orbit Intersection', 'Inclination',
#        'Perihelion Distance'],
#       dtype='object')
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# # **DB SCAN**

# %%
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt

# Select the features 
X_selected = nasa_df[selected_features]

# Selecting two attributes for visualization
X_visualize = X_selected[['Perihelion Distance', 'Minimum Orbit Intersection']]

# Apply DBSCAN clustering
dbscan = DBSCAN(eps=0.5, min_samples=5)
clusters = dbscan.fit_predict(X_visualize)

# Visualize the clusters
plt.figure(figsize=(10, 6))

# Plotting clusters for hazardous (True) objects
plt.scatter(X_visualize[y_resampled == True]['Minimum Orbit Intersection'], X_visualize[y_resampled == True]['Perihelion Distance'],
            c='red', label='Hazardous (True)')

# Plotting clusters for non-hazardous (False) objects
plt.scatter(X_visualize[y_resampled == False]['Minimum Orbit Intersection'],X_visualize[y_resampled == False]['Perihelion Distance'],
            c='blue', label='Non-Hazardous (False)')

plt.title('DBSCAN Clustering of Hazardous Objects')
plt.ylabel('Perihelion Distance')
plt.xlabel('Minimum Orbit Intersection')
plt.legend()
plt.show()
# Out:
# <ipython-input-94-8b4fda2ff0cc>:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   plt.scatter(X_visualize[y_resampled == True]['Minimum Orbit Intersection'], X_visualize[y_resampled == True]['Perihelion Distance'],
# <ipython-input-94-8b4fda2ff0cc>:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   plt.scatter(X_visualize[y_resampled == True]['Minimum Orbit Intersection'], X_visualize[y_resampled == True]['Perihelion Distance'],
# <ipython-input-94-8b4fda2ff0cc>:22: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   plt.scatter(X_visualize[y_resampled == False]['Minimum Orbit Intersection'],X_visualize[y_resampled == False]['Perihelion Distance'],
# <ipython-input-94-8b4fda2ff0cc>:22: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   plt.scatter(X_visualize[y_resampled == False]['Minimum Orbit Intersection'],X_visualize[y_resampled == False]['Perihelion Distance'],

# %% [markdown]
# # **Hierarchical Clustering**

# %%
import pandas as pd
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt

# Extract selected features and target variable
X_selected = nasa_df[selected_features]
y_hazardous = nasa_df['Hazardous']

# Encode target variable
y_encoded = y_hazardous.astype(int)

# Apply Hierarchical Clustering
clustering = AgglomerativeClustering(n_clusters=2, linkage='ward')
cluster_labels = clustering.fit_predict(X_selected)

# Scatter plot
plt.figure(figsize=(10, 6))

# Plot points for each cluster
plt.scatter(X_selected.iloc[cluster_labels == 0]['Minimum Orbit Intersection'],
            X_selected.iloc[cluster_labels == 0]['Perihelion Distance'],
            c='blue', label='Non-Hazardous')

plt.scatter(X_selected.iloc[cluster_labels == 1]['Minimum Orbit Intersection'],
            X_selected.iloc[cluster_labels == 1]['Perihelion Distance'],
            c='red', label='Hazardous')

plt.title('Hierarchical Clustering of Hazardous Asteroids')
plt.xlabel('Minimum Orbit Intersection')
plt.ylabel('Perihelion Distance')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # **Agglomerative Clustering**

# %%
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt

# Extract selected features and target variable
X_selected = nasa_df[selected_features]
y_hazardous = nasa_df['Hazardous']

# Encode target variable
y_encoded = y_hazardous.astype(int)

# Apply Agglomerative clustering
agg_clustering = AgglomerativeClustering(n_clusters=2)
cluster_labels = agg_clustering.fit_predict(X_selected)

# Scatter plot
plt.figure(figsize=(10, 6))

# Plot points for each cluster
plt.scatter(X_selected.iloc[cluster_labels == 0]['Minimum Orbit Intersection'],
            X_selected.iloc[cluster_labels == 0]['Perihelion Distance'],
            c='blue', label='Non-Hazardous')

plt.scatter(X_selected.iloc[cluster_labels == 1]['Minimum Orbit Intersection'],
            X_selected.iloc[cluster_labels == 1]['Perihelion Distance'],
            c='red', label='Hazardous')

plt.title('Agglomerative Clustering of Hazardous Asteroids')
plt.xlabel('Minimum Orbit Intersection')
plt.ylabel('Perihelion Distance')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # **Linear Regression**

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt

# Extract selected features and target variable
X_selected = nasa_df[['Minimum Orbit Intersection', 'Perihelion Distance']]
y_hazardous = nasa_df['Hazardous']

# Initialize and fit the linear regression model
model = LinearRegression()
model.fit(X_selected, y_hazardous)

# Predictions
y_pred = model.predict(X_selected)

# Scatter plot with best fit line
plt.figure(figsize=(10, 6))

# Scatter plot of actual data
plt.scatter(X_selected['Minimum Orbit Intersection'], X_selected['Perihelion Distance'], color='blue', label='Actual vs Predicted')

# Plotting the best fit line
plt.plot([y_pred.min(), y_pred.max()], [y_pred.min(), y_pred.max()], color='red', linestyle='--', linewidth=2, label='Best Fit Line')

plt.title('Linear Regression: Actual vs Predicted Hazardous')
plt.xlabel('Actual Hazardous')
plt.ylabel('Predicted Hazardous')
plt.legend()
plt.grid(True)
plt.show()

# %%
rounded = []
for i in range(len(y_pred)):
  rounded.append(round(y_pred[i]))
np.array(rounded)

print(classification_report(y_hazardous, rounded))
print(np.std(y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.84      1.00      0.91      3932
#         True       0.00      0.00      0.00       755
#
#     accuracy                           0.84      4687
#    macro avg       0.42      0.50      0.46      4687
# weighted avg       0.70      0.84      0.77      4687
#
# 0.11590256912250707
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
